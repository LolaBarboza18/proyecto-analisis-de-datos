# %%
# %pip install python-dotenv

import os
from dotenv import load_dotenv
import pandas as pd
from sqlalchemy import create_engine

load_dotenv()

DB_URI = os.getenv("SUPABASE_DB_URI")
engine = create_engine(DB_URI)
df_peliculas = pd.read_csv('../data/raw/imdb_movies.csv')
df_peliculas.to_sql('peliculas_raw', con=engine, if_exists='replace', index=False)
print("¡Éxito! Tabla 'peliculas_raw' creada y alojada en Supabase.")

from sqlalchemy import inspect, create_engine

# 1. Asegúrate de poner tu URI exacta de Supabase

DB_URI = "postgresql://postgres:Esnupiba_1015@db.rbtrppjxhsdbsseyrkiu.supabase.co:5432/postgres"
engine = create_engine(DB_URI)

# 2. Inspeccionamos la base de datos
inspector = inspect(engine)
tablas_existentes = inspector.get_table_names()

print("Tablas encontradas en Supabase:", tablas_existentes)
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# C:\Users\LOLA\AppData\Local\Temp\ipykernel_6680\1539539409.py:12: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_peliculas = pd.read_csv('../data/raw/imdb_movies.csv')
# ¡Éxito! Tabla 'peliculas_raw' creada y alojada en Supabase.
# Tablas encontradas en Supabase: ['peliculas_procesadas', 'peliculas_raw']
